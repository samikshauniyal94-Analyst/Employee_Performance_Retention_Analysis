# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Samiksha\\Downloads\\employees_dataset.csv")

# %%
df.head()
# Out:
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score
# 0                  1                      1           0                  77
# ...

# %%
df.isnull()
# Out:
#        employee_id  department  region  education  gender  \
# 0            False       False   False      False   False
# 1            False       False   False      False   False
# 2            False       False   False      False   False
# 3            False       False   False      False   False
# 4            False       False   False      False   False
# ...            ...         ...     ...        ...     ...
# 17412        False       False   False      False   False
# 17413        False       False   False      False   False
# 17414        False       False   False      False   False
# 17415        False       False   False      False   False
# 17416        False       False   False      False   False
#
#        recruitment_channel  no_of_trainings    age  previous_year_rating  \
# 0                    False            False  False                  True
# 1                    False            False  False                 False
# ...

# %%
df.isnull().sum()
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %%
df['previous_year_rating'].mean()
# Out:
# np.float64(3.3454590756197833)

# %%
df['education'].mode()
# Out:
# 0    Bachelors
# Name: education, dtype: object

# %%
df.fillna({"education" : df['education'].mode()[0],"previous_year_rating" : df['previous_year_rating'].mean()})
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17414        49584                 HR   region_7  Bachelors      m
# 17415        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24              3.345459
# ...

# %%
df['education'].fillna(value=df['education'].mode()[0])
# Out:
# 0        Bachelors
# 1        Bachelors
# 2        Bachelors
# 3        Bachelors
# 4        Bachelors
#            ...
# 17412    Bachelors
# 17413    Bachelors
# 17414    Bachelors
# 17415    Bachelors
# 17416    Bachelors
# Name: education, Length: 17417, dtype: object

# %%
df['education'].fillna(value=df['education'].mode()[0])
# Out:
# 0        Bachelors
# 1        Bachelors
# 2        Bachelors
# 3        Bachelors
# 4        Bachelors
#            ...
# 17412    Bachelors
# 17413    Bachelors
# 17414    Bachelors
# 17415    Bachelors
# 17416    Bachelors
# Name: education, Length: 17417, dtype: object

# %%
df['previous_year_rating'].fillna(value= 3)
# Out:
# 0        3.0
# 1        3.0
# 2        1.0
# 3        2.0
# 4        4.0
#         ...
# 17412    5.0
# 17413    1.0
# 17414    1.0
# 17415    1.0
# 17416    5.0
# Name: previous_year_rating, Length: 17417, dtype: float64

# %%
df.isnull().sum()
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %%
df['previous_year_rating'].fillna(value= 3, inplace=True)
# Out:
# C:\Users\Samiksha\AppData\Local\Temp\ipykernel_18304\963328117.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_year_rating'].fillna(value= 3, inplace=True)

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education                771
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating       0
# length_of_service          0
# KPIs_met_more_than_80      0
# awards_won                 0
# avg_training_score         0
# dtype: int64

# %%
df['education'].fillna(value=df['education'].mode()[0],inplace=True)
# Out:
# C:\Users\Samiksha\AppData\Local\Temp\ipykernel_18304\1326561257.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['education'].fillna(value=df['education'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# employee_id              0
# department               0
# region                   0
# education                0
# gender                   0
# recruitment_channel      0
# no_of_trainings          0
# age                      0
# previous_year_rating     0
# length_of_service        0
# KPIs_met_more_than_80    0
# awards_won               0
# avg_training_score       0
# dtype: int64

# %%
df.head()
# Out:
#    employee_id         department     region  education gender  \
# 0         8724         Technology  region_26  Bachelors      m
# 1        74430                 HR   region_4  Bachelors      f
# 2        72255  Sales & Marketing  region_13  Bachelors      m
# 3        38562        Procurement   region_2  Bachelors      f
# 4        64486            Finance  region_29  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   3.0
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met_more_than_80  awards_won  avg_training_score
# 0                  1                      1           0                  77
# ...

# %%
dept_perf = df.groupby('department')['previous_year_rating'].mean()

# %%
dept_perf
# Out:
# department
# Analytics            3.468474
# Finance              3.487531
# HR                   3.507803
# Legal                3.382530
# Operations           3.631385
# Procurement          3.234375
# R&D                  3.659639
# Sales & Marketing    3.096189
# Technology           3.143702
# Name: previous_year_rating, dtype: float64

# %%
dept_perf.plot(kind='bar', figsize=(8,4), title="Average Performance by Department",color='blue')
plt.ylabel("previous_year_rating")
plt.show()

# %%
df_kpi = df.groupby('KPIs_met_more_than_80')['previous_year_rating'].mean()

# %%
df_kpi
# Out:
# KPIs_met_more_than_80
# 0    3.01782
# 1    3.85552
# Name: previous_year_rating, dtype: float64

# %%
df_kpii=df.groupby('KPIs_met_more_than_80')['avg_training_score'].mean()

# %%
df_kpii
# Out:
# KPIs_met_more_than_80
# 0    62.454106
# 1    64.466720
# Name: avg_training_score, dtype: float64

# %%
plt.figure(figsize=(6,5))
plt.title('Average training score vs KPI')
plt.bar(['KPI<80','KPI>80'],df.groupby('KPIs_met_more_than_80')['avg_training_score'].mean(),color='blue')
plt.ylabel('Average training score')
plt.show()

# %%
df.groupby('awards_won')['avg_training_score'].mean()
# Out:
# awards_won
# 0    63.015050
# 1    69.916462
# Name: avg_training_score, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x='age', y='length_of_service', data=df,color='orange')
plt.title('Retention by Age Group')
plt.show()

# %%
df.groupby('education')['avg_training_score'].mean()
# Out:
# education
# Bachelors          62.735557
# Below Secondary    65.902098
# Masters & above    64.134270
# Name: avg_training_score, dtype: float64

# %%
df_edu = df.groupby('education')['length_of_service'].mean()

# %%
df_edu
# Out:
# education
# Bachelors          5.276892
# Below Secondary    1.762238
# Masters & above    7.373270
# Name: length_of_service, dtype: float64

# %%
df_edu.plot(kind='bar', figsize=(8,4), title="Retention  rate by education",color='blue')

plt.ylabel('length_of_service')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x='avg_training_score', y='length_of_service', data=df,color='orange')
plt.title('Retention vs avg_training_score')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x='avg_training_score', y='previous_year_rating', data=df,color='orange')
plt.title('Performance by training score')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 5))
sns.barplot(
   data=df,
    x='department',
    y='avg_training_score',
)
plt.title('Department Performance by training score')
plt.show()
